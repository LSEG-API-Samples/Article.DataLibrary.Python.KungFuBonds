# %% [markdown]
# ----
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Content layer - Search
# This notebook demonstrates how to use the Search service of the Refinitiv Data Platform to search for Kung fu bonds

# %% [markdown]
# #### Learn more
#
# To learn more about the Refinitiv Data Library for Python please join the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the Refinitiv Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Refinitiv Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The Refinitiv Developer Community will be happy to help.
#
# ----

# %% [markdown]
# ## Some Imports to start with

# %%
import refinitiv.data as rd
from refinitiv.data.content import search

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x28c660195b0 {name='workspace'}>

# %% [markdown]
# ## Retrieve data
# ### Search with Filter Expressions
# #### Access Layer
# The **Access Layer** is the easiest way to get Refinitiv data. It provides simple interfaces allowing you to quickly prototype solutions in interactive environments such as Jupyter Notebooks.

# %%
rd.discovery.search(
    view = rd.discovery.Views.GOV_CORP_INSTRUMENTS,
    top = 10,
    filter = "((DbType eq 'GOVT' or DbType eq 'CORP' or DbType eq 'AGNC' or DbType eq 'OMUN' or DbType eq 'OTHR') and IsActive eq true and (RCSParentDomicileGenealogy in ('G:53' 'G:3H') and RCSCurrencyLeaf eq 'US Dollar' and RCSCountryGenealogy ne 'M:DQ\G:B6'))",
    select = "RIC,EJVAssetID,DTSubjectName,BusinessEntity,PI,SearchAllCategoryv3,SearchAllCategoryv2,SearchAllCategory,DBSTicker,CouponRate,MaturityDate,IssueDate,ISIN,RCSCurrencyLeaf,RCSCountryLeaf,DbTypeDescription,InstrumentTypeDescription,RCSCouponTypeGenealogy,FaceIssuedUSD,RCSBondGradeLeaf,RCSParentDomicileLeaf,RCSParentDomicileGenealogy,RCSCountryGenealogy"
)
# Out:
#                  RIC          EJVAssetID  \
# 0       VG226919449=  0x00102cafe57a2824
# 1       CN207889792=  0x00102c61d42f1eb8
# 2       BM194085214=  0x00102c1e3d211826
# 3       CN223856128=  0x00102cd82c96257b
# 4       CN245541155=  0x00102c18171a3118
# 5       CN209223643=  0x00102c33b5561ef2
# 6       CN218485685=  0x00102ca4306122eb
# 7  XS2462270989=TEMK  0x00102c5618003143
# 8       CN246777420=  0x00102ce5fd673172
# 9       KY205058486=  0x00102c24d0921c46
#
#                                        DTSubjectName  \
# 0  Powerchina Roadbridge Group (British Virgin Is...
# 1                      Geely Automobile Holdings Ltd
# 2                                Celestial Miles Ltd
# 3                      Bank of Communications Co Ltd
# 4                                 Dianjian Haiyu Ltd
# 5    China Construction Bank Corp (Hong Kong Branch)
# 6        China Huadian Overseas Development 2018 Ltd
# 7                                  MIE Holdings Corp
# 8                        Nanyang Commercial Bank Ltd
# 9                                    FEC Finance Ltd
#
#                    BusinessEntity                  PI SearchAllCategoryv3  \
# 0  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102cafe57a2824               Bonds
# 1  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c61d42f1eb8               Bonds
# 2  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c1e3d211826               Bonds
# 3  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102cd82c96257b               Bonds
# 4  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c18171a3118               Bonds
# 5  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c33b5561ef2               Bonds
# 6  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102ca4306122eb               Bonds
# 7  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c5618003143               Bonds
# 8  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102ce5fd673172               Bonds
# 9  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c24d0921c46               Bonds
#
#   SearchAllCategoryv2 SearchAllCategory DBSTicker  CouponRate  ...  \
# 0               Bonds             Bonds     PWRGB        3.08  ...
# 1               Bonds             Bonds     GEEAU         4.0  ...
# 2               Bonds             Bonds    NWSHLL        5.75  ...
# 3               Bonds             Bonds     BKCOM         3.8  ...
# 4               Bonds             Bonds    PWRCCD        4.25  ...
# 5               Bonds             Bonds    CNCHKG        4.31  ...
# 6               Bonds             Bonds     CHODT       3.375  ...
# 7               Bonds             Bonds     MIEHO         0.0  ...
# 8               Bonds             Bonds    CCASMN         6.5  ...
# 9               Bonds             Bonds    FARECF       7.375  ...
#
#   RCSCurrencyLeaf RCSCountryLeaf DbTypeDescription InstrumentTypeDescription  \
# 0       US Dollar       Eurobond         Corporate                      Note
# 1       US Dollar       Eurobond         Corporate          Capital Security
# 2       US Dollar       Eurobond         Corporate          Capital Security
# 3       US Dollar       Eurobond         Corporate          Capital Security
# 4       US Dollar       Eurobond         Corporate                      Note
# 5       US Dollar       Eurobond         Corporate                      Note
# 6       US Dollar       Eurobond         Corporate          Capital Security
# 7       US Dollar       Eurobond         Corporate                      Bond
# 8       US Dollar       Eurobond         Corporate          Capital Security
# 9       US Dollar       Eurobond         Corporate          Capital Security
#
#   RCSCouponTypeGenealogy FaceIssuedUSD  RCSBondGradeLeaf  \
# 0        M:1EU\A:KS\A:KT     500000000  Investment Grade
# 1        M:1EU\A:KS\A:KT     500000000  Investment Grade
# 2        M:1EU\A:KS\A:KT    1300000000              <NA>
# 3        M:1EU\A:KS\A:KT    2800000000        High Yield
# 4        M:1EU\A:KS\A:KT     500000000  Investment Grade
# 5        M:1EU\A:C1\A:25     500000000              <NA>
# 6        M:1EU\A:KS\A:KT     500000000  Investment Grade
# 7        M:1EU\A:C0\A:2L     248394000              <NA>
# 8        M:1EU\A:KS\A:KT     650000000        High Yield
# 9        M:1EU\A:KS\A:KT     360000000              <NA>
#
#    RCSParentDomicileLeaf                         RCSParentDomicileGenealogy  \
# 0       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 1       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 2              Hong Kong  M:DH\G:K\G:S\G:6\G:3H|M:DQ\G:1\G:3H|M:DQ\G:AQ\...
# 3       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 4       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 5       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 6       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 7              Hong Kong  M:DH\G:K\G:S\G:6\G:3H|M:DQ\G:1\G:3H|M:DQ\G:AQ\...
# 8       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 9              Hong Kong  M:DH\G:K\G:S\G:6\G:3H|M:DQ\G:1\G:3H|M:DQ\G:AQ\...
#
#   RCSCountryGenealogy
# 0           M:1EW\A:S
# 1           M:1EW\A:S
# 2           M:1EW\A:S
# 3           M:1EW\A:S
# 4           M:1EW\A:S
# 5           M:1EW\A:S
# 6           M:1EW\A:S
# 7           M:1EW\A:S
# 8           M:1EW\A:S
# 9           M:1EW\A:S
#
# [10 rows x 22 columns]

# %% [markdown]
# #### Content Layer
# The **Content Layer** is the foundation of the Access Layer. It provides developers with interfaces suitable for more advanced use cases (synchronous function calls, async/await, event driven).

# %%
response = search.Definition(
    view = search.Views.GOV_CORP_INSTRUMENTS,
    top = 10,
    filter = "((DbType eq 'GOVT' or DbType eq 'CORP' or DbType eq 'AGNC' or DbType eq 'OMUN' or DbType eq 'OTHR') and IsActive eq true and (RCSParentDomicileGenealogy in ('G:53' 'G:3H') and RCSCurrencyLeaf eq 'US Dollar' and RCSCountryGenealogy ne 'M:DQ\G:B6'))",
    select = "RIC,EJVAssetID,DTSubjectName,BusinessEntity,PI,SearchAllCategoryv3,SearchAllCategoryv2,SearchAllCategory,DBSTicker,CouponRate,MaturityDate,IssueDate,ISIN,RCSCurrencyLeaf,RCSCountryLeaf,DbTypeDescription,InstrumentTypeDescription,RCSCouponTypeGenealogy,FaceIssuedUSD,RCSBondGradeLeaf,RCSParentDomicileLeaf,RCSParentDomicileGenealogy,RCSCountryGenealogy"
).get_data()
response.data.df
# Out:
#                  RIC          EJVAssetID  \
# 0       VG226919449=  0x00102cafe57a2824
# 1       CN207889792=  0x00102c61d42f1eb8
# 2       BM194085214=  0x00102c1e3d211826
# 3       CN223856128=  0x00102cd82c96257b
# 4       CN245541155=  0x00102c18171a3118
# 5       CN209223643=  0x00102c33b5561ef2
# 6       CN218485685=  0x00102ca4306122eb
# 7  XS2462270989=TEMK  0x00102c5618003143
# 8       CN246777420=  0x00102ce5fd673172
# 9       KY205058486=  0x00102c24d0921c46
#
#                                        DTSubjectName  \
# 0  Powerchina Roadbridge Group (British Virgin Is...
# 1                      Geely Automobile Holdings Ltd
# 2                                Celestial Miles Ltd
# 3                      Bank of Communications Co Ltd
# 4                                 Dianjian Haiyu Ltd
# 5    China Construction Bank Corp (Hong Kong Branch)
# 6        China Huadian Overseas Development 2018 Ltd
# 7                                  MIE Holdings Corp
# 8                        Nanyang Commercial Bank Ltd
# 9                                    FEC Finance Ltd
#
#                    BusinessEntity                  PI SearchAllCategoryv3  \
# 0  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102cafe57a2824               Bonds
# 1  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c61d42f1eb8               Bonds
# 2  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c1e3d211826               Bonds
# 3  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102cd82c96257b               Bonds
# 4  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c18171a3118               Bonds
# 5  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c33b5561ef2               Bonds
# 6  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102ca4306122eb               Bonds
# 7  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c5618003143               Bonds
# 8  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102ce5fd673172               Bonds
# 9  INSTRUMENTxFIXEDINCOMExGOVCORP  0x00102c24d0921c46               Bonds
#
#   SearchAllCategoryv2 SearchAllCategory DBSTicker  CouponRate  ...  \
# 0               Bonds             Bonds     PWRGB        3.08  ...
# 1               Bonds             Bonds     GEEAU         4.0  ...
# 2               Bonds             Bonds    NWSHLL        5.75  ...
# 3               Bonds             Bonds     BKCOM         3.8  ...
# 4               Bonds             Bonds    PWRCCD        4.25  ...
# 5               Bonds             Bonds    CNCHKG        4.31  ...
# 6               Bonds             Bonds     CHODT       3.375  ...
# 7               Bonds             Bonds     MIEHO         0.0  ...
# 8               Bonds             Bonds    CCASMN         6.5  ...
# 9               Bonds             Bonds    FARECF       7.375  ...
#
#   RCSCurrencyLeaf RCSCountryLeaf DbTypeDescription InstrumentTypeDescription  \
# 0       US Dollar       Eurobond         Corporate                      Note
# 1       US Dollar       Eurobond         Corporate          Capital Security
# 2       US Dollar       Eurobond         Corporate          Capital Security
# 3       US Dollar       Eurobond         Corporate          Capital Security
# 4       US Dollar       Eurobond         Corporate                      Note
# 5       US Dollar       Eurobond         Corporate                      Note
# 6       US Dollar       Eurobond         Corporate          Capital Security
# 7       US Dollar       Eurobond         Corporate                      Bond
# 8       US Dollar       Eurobond         Corporate          Capital Security
# 9       US Dollar       Eurobond         Corporate          Capital Security
#
#   RCSCouponTypeGenealogy FaceIssuedUSD  RCSBondGradeLeaf  \
# 0        M:1EU\A:KS\A:KT     500000000  Investment Grade
# 1        M:1EU\A:KS\A:KT     500000000  Investment Grade
# 2        M:1EU\A:KS\A:KT    1300000000              <NA>
# 3        M:1EU\A:KS\A:KT    2800000000        High Yield
# 4        M:1EU\A:KS\A:KT     500000000  Investment Grade
# 5        M:1EU\A:C1\A:25     500000000              <NA>
# 6        M:1EU\A:KS\A:KT     500000000  Investment Grade
# 7        M:1EU\A:C0\A:2L     248394000              <NA>
# 8        M:1EU\A:KS\A:KT     650000000        High Yield
# 9        M:1EU\A:KS\A:KT     360000000              <NA>
#
#    RCSParentDomicileLeaf                         RCSParentDomicileGenealogy  \
# 0       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 1       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 2              Hong Kong  M:DH\G:K\G:S\G:6\G:3H|M:DQ\G:1\G:3H|M:DQ\G:AQ\...
# 3       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 4       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 5       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 6       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 7              Hong Kong  M:DH\G:K\G:S\G:6\G:3H|M:DQ\G:1\G:3H|M:DQ\G:AQ\...
# 8       China (Mainland)  M:DH\G:K\G:S\G:6\G:53|M:DQ\G:1\G:53|M:DQ\G:AQ\...
# 9              Hong Kong  M:DH\G:K\G:S\G:6\G:3H|M:DQ\G:1\G:3H|M:DQ\G:AQ\...
#
#   RCSCountryGenealogy
# 0           M:1EW\A:S
# 1           M:1EW\A:S
# 2           M:1EW\A:S
# 3           M:1EW\A:S
# 4           M:1EW\A:S
# 5           M:1EW\A:S
# 6           M:1EW\A:S
# 7           M:1EW\A:S
# 8           M:1EW\A:S
# 9           M:1EW\A:S
#
# [10 rows x 22 columns]

# %% [markdown]
# ###### Close the session

# %%
rd.close_session()

# %% [markdown]
# ### Thank you
